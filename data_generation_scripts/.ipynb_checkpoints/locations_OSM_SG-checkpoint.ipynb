# %%
import osmnx as ox
import matplotlib.pyplot as plt
from shapely.geometry import Polygon, Point
import geopandas as gpd
import pandas as pd

# %%
COUNTY = '037'
AREA = 'Davidson'

# %%
# input Hamilton county geo file
county_cbg = gpd.read_file('../data/Tennessee Census Block Groups/tl_2020_47_bg.shp')
county_cbg = county_cbg[county_cbg.COUNTYFP==COUNTY]
county_cbg = county_cbg.to_crs('epsg:4326')

# %%
minx, miny, maxx, maxy = county_cbg.geometry.total_bounds

# %%
# minx, miny, maxx, maxy

# %%
#finding all buildings
tags = {'building': True}
buildings = ox.geometries_from_bbox(miny, maxy, maxx, minx, tags)
# buildings = ox.geometries_from_bbox(34.854382885097905, 35.935532323321, -84.19759521484375, -85.553161621093756, tags)

# %%
#aggregating all residential tags
pd.set_option('display.max_columns', None)
res_build = buildings[(buildings.building == 'residential') | (buildings.building == 'bungalow') | (buildings.building == 'cabin') | (buildings.building == 'dormitory') | (buildings.building == 'hotel') | (buildings.building == 'house') | (buildings.building == 'semidetached_house') | (buildings.building == 'barracks') | (buildings.building == 'farm') | (buildings.building == 'ger') | (buildings.building == 'houseboat') | (buildings.building == 'static_caravan') | (buildings.building == 'terrace')].reset_index()[['osmid', 'geometry', 'nodes', 'building', 'name', 'source']].sjoin(county_cbg)
res_build.geometry = res_build.geometry.apply(lambda x: x.centroid if x.geom_type =='Polygon' else x)

# %%
#saving residential buildings
res_build.to_csv(f'../data/county_residential_buildings.csv', index=False)

# %%
pd.set_option('display.max_columns', None)

#work tags

com_build = buildings[(buildings.building == 'commercial') | (buildings.building == 'industrial') | (buildings.building == 'kiosk') | (buildings.building == 'office') | (buildings.building == 'retail') | (buildings.building == 'supermarket') | (buildings.building == 'warehouse')].reset_index()[['osmid', 'geometry', 'nodes', 'building', 'name', 'source']].sjoin(county_cbg)
civ_build = buildings[(buildings.building == 'bakehouse') | (buildings.building == 'civic') | (buildings.building == 'college') | (buildings.building == 'fire_station') | (buildings.building == 'government') | (buildings.building == 'hospital') | (buildings.building == 'kindergarten') | (buildings.building == 'public') | (buildings.building == 'school') | (buildings.building == 'train_station') | (buildings.building == 'transportation') | (buildings.building == 'university')].reset_index()[['osmid', 'geometry', 'nodes', 'building', 'name', 'source']].sjoin(county_cbg)

com_build.geometry = com_build.geometry.apply(lambda x: x.centroid if x.geom_type =='Polygon' else x)
civ_build.geometry = civ_build.geometry.apply(lambda x: x.centroid if x.geom_type =='Polygon' else x)

# %%
def func(row):
    str(Point(gpd.points_from_xy(row.INTPTLAT, row.INTPTLON)[0]))

# %%
#converting the default internal point of each cbg to a shapely Point
res_build['intpt'] = res_build[['INTPTLAT', 'INTPTLON']].apply(lambda x: func, axis=1)

# %% [markdown]
# ## adding safegraph poi locations

# %%
# add safegraph extracted data

# sg = gpd.read_file('path to safegraph file') # path removed due to privacy concerns
sg = pd.read_csv('../data/sg_poi_cbgs.csv') # path removed due to privacy concerns

# sg.longitude = sg.longitude.astype(float)
# sg.latitude = sg.latitude.astype(float)

sg.longitude = sg.longitude.astype(float)
sg.latitude = sg.latitude.astype(float)
geom = [Point(xy) for xy in zip(sg.longitude, sg.latitude)]
sg = gpd.GeoDataFrame(sg, geometry = geom, crs='epsg:4326')

# %%
#adding in safegraph POI locations to OSM work locations

t1 = (sg[['poi_cbg', 'geometry']].rename({'poi_cbg':'GEOID'},axis=1).append(com_build[['GEOID', 'geometry']]).append(civ_build[['GEOID', 'geometry']]))
# t1 = com_build[['GEOID', 'geometry']].append(civ_build[['GEOID', 'geometry']])
t1.GEOID = t1.GEOID.astype(str).apply(lambda x: x.split('.')[0])

# saving work buildings to file 
t1.to_csv(f'../data/county_work_loc_poi_com_civ.csv', index=False)

# %%
sg[['poi_cbg', 'geometry']],
t1
# Out:
# (         poi_cbg                    geometry
#  0   470370111002  POINT (-86.72522 36.23135)
#  1   470370122001  POINT (-86.73747 36.16859)
#  2   470370127013  POINT (-86.80545 36.22143)
#  3   470370133003  POINT (-86.84715 36.16072)
#  4   470370144001  POINT (-86.79372 36.15991)
#  5   470370151003  POINT (-86.69016 36.16094)
#  6   470370152002  POINT (-86.68034 36.16969)
#  7   470370153002  POINT (-86.68017 36.21959)
#  8   470370153004  POINT (-86.69621 36.22551)
#  9   470370154023  POINT (-86.62396 36.20284)
#  10  470370156131  POINT (-86.68987 36.08508)
#  11  470370156182  POINT (-86.63042 36.07524)
#  12  470370156252  POINT (-86.63547 36.13222)
#  13  470370156261  POINT (-86.63765 36.07077)
#  14  470370159001  POINT (-86.74709 36.13846)
#  15  470370159002  POINT (-86.73925 36.13223)
#  16  470370162002  POINT (-86.78095 36.13457)
#  17  470370164002  POINT (-86.80060 36.13549)
#  18  470370168003  POINT (-86.81973 36.13799)
#  19  470370169001  POINT (-86.80170 36.13006)
#  20  470370169002  POINT (-86.79720 36.11729)
#  21  470370170001  POINT (-86.77868 36.13221)
#  22  470370173002  POINT (-86.74629 36.11416)
#  23  470370173003  POINT (-86.74268 36.12572)
#  24  470370174011  POINT (-86.74220 36.11127)
#  25  470370181013  POINT (-86.86928 36.14759)
#  26  470370181021  POINT (-86.87925 36.13848)
#  27  470370182011  POINT (-86.88153 36.13881)
#  28  470370184043  POINT (-86.92173 36.07371)
#  29  470370184053  POINT (-86.95440 36.04227)
#  30  470370184082  POINT (-86.96056 36.04299)
#  31  470370184091  POINT (-86.95449 36.07925)
#  32  470370189011  POINT (-86.72754 36.08156)
#  33  470370189023  POINT (-86.73423 36.07104)
#  34  470370189042  POINT (-86.72259 36.07010)
#  35  470370190031  POINT (-86.70247 36.08422)
#  36  470370191062  POINT (-86.74165 36.04100)
#  37  470370191101  POINT (-86.71461 36.05406)
#  38  470370191103  POINT (-86.71278 36.04589)
#  39  470370192001  POINT (-86.75930 36.17234)
#  40  470370193001  POINT (-86.77238 36.17096)
#  41  470370196002  POINT (-86.73011 36.15240)
#  42  470379802001  POINT (-86.76351 36.10749),)

# %%
ax=county_cbg.plot(figsize=(10, 10), color='None', edgecolor="black", linewidth=0.4)
t1.plot(figsize=(10, 10), ax=ax, markersize=0.1)
# Out:
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>

# %%
ax=county_cbg.plot(figsize=(10, 10), color='None', edgecolor="black", linewidth=0.4)
res_build.plot(figsize=(10, 10), ax=ax, markersize=0.1)
# Out:
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\geopandas\plotting.py:74: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if mpl >= LooseVersion("3.4") or (mpl > LooseVersion("3.3.2") and "+" in mpl):
# c:\Users\senr1\AppData\Local\Programs\Python\Python37\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# <AxesSubplot:>
